# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4],[5,6,7,8])

# %%
plt.plot([1,2,3,4],[5,6,7,8],linewidth=10)

# %%
plt.plot([1,2,3,4],[5,6,7,8],linewidth=10,color='y')

# %%
plt.plot([1,2,3,4],[5,6,7,8],linewidth=5,ls=':')

# %%
EnergySourse=['Nuclear','Hydro','Gas','Oil','Coal','Biofuel']
Energy=[5,6,15,22,24,8]
plt.bar(EnergySourse,Energy)
# Out:
# <BarContainer object of 6 artists>

# %%
EnergySourse=['Nuclear','Hydro','Gas','Oil','Coal','Biofuel']
Energy=[5,6,15,22,24,8]
plt.bar(EnergySourse,Energy)
plt.title("Energy output from various fuel sources")
# Out:
# Text(0.5, 1.0, 'Energy output from various fuel sources')

# %%
EnergySourse=['Nuclear','Hydro','Gas','Oil','Coal','Biofuel']
Energy=[5,6,15,22,24,8]
plt.bar(EnergySourse,Energy)
plt.title("Energy output from various fuel sources")
plt.xlabel("Source")
plt.ylabel("Unit")
# Out:
# Text(0, 0.5, 'Unit')

# %%
x1=[2,3,4,5,6]
y1=[10,15,20,25,19]
x2=[2,3,4,5,6]
y2=[15,25,18,16,20]
plt.bar(x1,y1)
plt.bar(x2,y2)
plt.title("First graph")
plt.xlabel("X label")
plt.ylabel("Y label")
# Out:
# Text(0, 0.5, 'Y label')

# %%
x1=[2,3,4,5,6]
y1=[10,15,20,25,19]
x2=[2,3,4,5,6]
y2=[15,25,18,16,20]
plt.bar(x1,y1,alpha=0.5)
plt.bar(x2,y2,alpha=0.5)
plt.title("First graph")
plt.xlabel("X label")
plt.ylabel("Y label")
# Out:
# Text(0, 0.5, 'Y label')

# %%
x1=[2,3,4,5,6]
y1=[10,15,20,25,19]
x2=[2,3,4,5,6]
y2=[15,25,18,16,20]
plt.bar(x1,y1,alpha=0.5,label="First graph")
plt.bar(x2,y2,alpha=0.5,label="Second graph")
plt.title("First graph")
plt.xlabel("X label")
plt.ylabel("Y label")
plt.legend()

# %%
x1=[2,3,4,5,6]
y1=[10,15,20,25,19]
x2=[2,3,4,5,6]
y2=[15,25,18,16,20]
plt.bar(x1,y1,width=0.9,label="First graph")
plt.bar(x2,y2,width=0.7,label="Second graph")
plt.title("First graph")
plt.xlabel("X label")
plt.ylabel("Y label")
plt.legend()

# %%
x1=[2,3,4,5,6]
y1=[10,15,20,25,19]
x2=[2,3,4,5,6]
y2=[15,25,18,16,20]
plt.figure(figsize=(15,8))
plt.bar(x1,y1,width=0.9,label="First graph")
plt.bar(x2,y2,width=0.7,label="Second graph")
plt.title("First graph")
plt.xlabel("X label")
plt.ylabel("Y label")
plt.legend()

# %% [markdown]
# # Histogram

# %%
import numpy as np
height = np.array(np.arange(150,200,2))
height
# Out:
# array([150, 152, 154, 156, 158, 160, 162, 164, 166, 168, 170, 172, 174,
#        176, 178, 180, 182, 184, 186, 188, 190, 192, 194, 196, 198])

# %%
plt.hist(height,rwidth=0.8)
# Out:
# (array([3., 2., 3., 2., 2., 3., 2., 3., 2., 3.]),
#  array([150. , 154.8, 159.6, 164.4, 169.2, 174. , 178.8, 183.6, 188.4,
#         193.2, 198. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(height,rwidth=.7)
# Out:
# (array([3., 2., 3., 2., 2., 3., 2., 3., 2., 3.]),
#  array([150. , 154.8, 159.6, 164.4, 169.2, 174. , 178.8, 183.6, 188.4,
#         193.2, 198. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(height,rwidth=.7,bins=3)
# Out:
# (array([8., 8., 9.]),
#  array([150., 166., 182., 198.]),
#  <a list of 3 Patch objects>)

# %%
# custom bin
varbin=[150,165,175,190,200]
plt.hist(height,rwidth=.7,bins=varbin)
# Out:
# (array([8., 5., 7., 5.]),
#  array([150, 165, 175, 190, 200]),
#  <a list of 4 Patch objects>)

# %%
maleheight = np.arange(150,200,2)
femaleheight = np.arange(140,180,2)
plt.hist([maleheight,femaleheight],rwidth=.7,label=['male','female'])
plt.legend()

# %%
randnumbers = np.random.randn(100)
randnumbers
# Out:
# array([ 0.1488587 ,  0.07623661,  0.57173633,  1.69469236,  0.83750135,
#        -1.45199848, -0.72770881,  0.71909965,  0.21831301,  0.99728245,
#        -0.01357719, -0.76438588,  0.24281126, -0.41664935,  1.10051438,
#        -0.12944253,  1.81467236, -0.04348919, -0.42823048,  0.33315411,
#         1.42323526,  1.64039243, -1.42344564, -1.09398   , -0.1704023 ,
#        -0.63515876, -0.69549183,  0.40023325,  0.50711356, -1.30766835,
#        -0.53204481,  1.14838472,  0.96462818,  0.21116158,  0.13249005,
#        -0.16123215, -0.21971847,  0.31941325,  0.90065439,  0.87259797,
#         1.09089028,  0.96011216,  1.09083343,  2.03215625, -0.49414265,
#        -0.65097705, -1.31452723,  0.19790195, -0.8168824 ,  0.65194485,
#         0.87171862, -0.89336833, -0.33474099,  0.52043868, -1.18686933,
#        -1.3855404 ,  0.92012298,  0.19182697, -0.67272915, -1.48538091,
#        -2.88638912,  0.82746429,  0.54794779, -0.53573623, -0.75421687,
# ...

# %%
plt.hist(randnumbers,rwidth=.7)
# Out:
# (array([ 2.,  0.,  0.,  9., 13., 19., 22., 19., 10.,  6.]),
#  array([-3.25366001, -2.72507838, -2.19649675, -1.66791513, -1.1393335 ,
#         -0.61075188, -0.08217025,  0.44641138,  0.974993  ,  1.50357463,
#          2.03215625]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(randnumbers,rwidth=.7,orientation='horizontal')
# Out:
# (array([ 2.,  0.,  0.,  9., 13., 19., 22., 19., 10.,  6.]),
#  array([-3.25366001, -2.72507838, -2.19649675, -1.66791513, -1.1393335 ,
#         -0.61075188, -0.08217025,  0.44641138,  0.974993  ,  1.50357463,
#          2.03215625]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Scatter Plot

# %%
x = [1,3,5,7,9,11,13]
y = [25,30,21,67,63,55,30]

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,marker='x')

# %%
x1 = [1,3,5,7,9,11,13]
y1 = [25,30,21,67,63,55,65]
x2 = [1,3,5,7,9,11,13]
y2 = [30,24,65,45,39,55,21]

# %%
plt.scatter(x1,y1,c='r',marker="*")
plt.scatter(x2,y2,c='b',marker="*")

# %%
plt.scatter(x1,y1,c='r',marker="*",s=250)

# %%
import pandas as pd

# %%
df1 = pd.read_excel('./DataVis_data/SampleSuperstoreSales.xlsx',0)

# %%
df1.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
df1.shape
# Out:
# (8399, 21)

# %%
plt.scatter(df1['Sales'],df1['Discount'])
plt.xlabel("Sales")
plt.ylabel("Discount")
# Out:
# Text(0, 0.5, 'Discount')

# %%
plt.scatter(df1['Sales'],df1['Discount'],s=30)
plt.xlabel("Sales")
plt.ylabel("Discount")
# Out:
# Text(0, 0.5, 'Discount')

# %%
plt.scatter(df1['Sales'],df1['Discount'],s=300)
plt.xlabel("Sales")
plt.ylabel("Discount")
# Out:
# Text(0, 0.5, 'Discount')

# %% [markdown]
# ## stack chart

# %%
week = [1,2,3,4,5]
shift1 = [40,35,26,23,20]
shift2 = [40,32,40,45,50]
shift3 = [40,35,45,42,40]

# %%
plt.stackplot(week,shift1,shift2,shift3)

# %%
plt.stackplot(week,shift1,shift2,shift3,labels=['shift1','shift2','shift3'])
plt.legend()

# %%
df1['Ship Mode'].value_counts()
# Out:
# Regular Air       6270
# Delivery Truck    1146
# Express Air        983
# Name: Ship Mode, dtype: int64

# %%
radf = df1[df1['Ship Mode']=='Regular Air']

# %%
dtdf = df1[df1['Ship Mode']=='Delivery Truck']

# %%
eadf = df1[df1['Ship Mode']=='Express Air']

# %%
plt.plot(radf['Sales'],'b+')

# %%
plt.plot(eadf['Sales'],'b+')

# %%
indexd = np.arange(0,1146)

# %%
dtdf.index = indexd

# %%
plt.plot(dtdf['Sales'],'b+')

# %%
eadf.shape[0]
# Out:
# 983

# %%
indeea = np.arange(0,983)

# %%
eadf.index = indeea

# %%
plt.plot(eadf['Sales'],'b+')

# %%
radf.index = np.arange(0,radf.shape[0])

# %%
plt.plot(radf['Sales'],'b+')

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# /home/sk/anaconda3/lib/python3.8/site-packages/seaborn/utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file /home/sk/anaconda3/lib/python3.8/site-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
dfcars = sns.load_dataset('car_crashes')
dfcars.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# # Dispribition plot

# %%
sns.distplot(dfcars['not_distracted'])

# %%
sns.distplot(dfcars['not_distracted'],kde=False)

# %%
sns.distplot(dfcars['not_distracted'],kde=False,bins=60)

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(x='speeding',y='alcohol',data=dfcars,kind='reg');

# %%
sns.jointplot(x='speeding',y='alcohol',data=dfcars,kind='kde');

# %%
sns.jointplot(x='speeding',y='alcohol',data=dfcars,kind='hex');

# %% [markdown]
# # KDE plot

# %%
sns.pairplot(dfcars)

# %%
dftips = sns.load_dataset('tips')

# %%
dftips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(dftips)

# %%
sns.pairplot(dftips,hue='sex')

# %%
dfcrash = sns.load_dataset('car_crashes')

# %%
dfcrash.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ## styling

# %%
sns.set_style('darkgrid')
sns.jointplot(x='speeding', y='alcohol',data=dfcrash,kind='reg')

# %%
sns.set_style('white')
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y='alcohol',data=dfcrash,kind='reg')

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y='alcohol',data=dfcrash,kind='reg')

# %%
dftips = sns.load_dataset('tips')

# %%
dftips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.rugplot(dftips['tip'])

# %% [markdown]
# # Categorical plot

# %% [markdown]
# ## barplot

# %%
sns.barplot(x='sex',y='total_bill',data=dftips);

# %%
dftips[dftips['sex']=='Male']['total_bill'].mean()
# Out:
# 20.744076433121034

# %%
sns.barplot(x='sex',y='total_bill',data=dftips,estimator=np.median);

# %%
sns.barplot(x='sex',y='total_bill',data=dftips,ci=None);

# %%
sns.barplot(x='sex',y='total_bill',data=dftips,estimator=np.std);

# %%
sns.countplot(x='sex',data=dftips)

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x='day',y='total_bill',data=dftips)

# %%
sns.boxplot(x='day',y='total_bill',data=dftips,hue='sex')

# %%
sns.boxplot(x='day',y='total_bill',data=dftips,hue='sex')
plt.legend(loc=3)

# %% [markdown]
# # Strip plot

# %%
sns.stripplot(x='day',y='total_bill',data=dftips)

# %%
sns.stripplot(x='day',y='total_bill',data=dftips,jitter=.3)

# %%
sns.stripplot(x='day',y='total_bill',data=dftips,jitter=.3,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=dftips,jitter=.1,hue='sex',dodge=True)

# %%
dforder=pd.read_excel('DataVis_data/SampleSuperstoreSales.xlsx')

# %%
sns.relplot('Sales','Profit',data=dforder)

# %%
sns.relplot('Sales','Profit',data=dforder,hue='Order Priority')

# %%
sns.relplot('Sales','Profit',data=dforder,hue='Order Priority',style='Ship Mode')

# %%
sns.relplot('Sales','Profit',data=dforder,size='Discount')

# %%
sns.relplot('Sales','Profit',data=dforder,size='Discount',sizes=(25,100))

# %%
sns.relplot('Order Date','Sales',data=dforder,kind='line')

# %%
dforder['Year']=dforder['Order Date'].dt.year

# %%
dforder.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...  Province   Region  \
# 0      0.04     Regular Air  -213.2500       38.94  ...   Nunavut  Nunavut
# 1      0.07  Delivery Truck   457.8100      208.16  ...   Nunavut  Nunavut
# 2      0.01     Regular Air    46.7075        8.69  ...   Nunavut  Nunavut
# 3      0.08     Regular Air  1198.9710      195.99  ...   Nunavut  Nunavut
# 4      0.08     Regular Air    30.9400       21.78  ...   Nunavut  Nunavut
#
# ...

# %%
dforder['Year'].value_counts()
# Out:
# 2009    2153
# 2010    2142
# 2012    2102
# 2011    2002
# Name: Year, dtype: int64

# %%
sns.relplot('Year','Sales',data=dforder,kind='line')

# %%
sns.relplot('Year','Sales',data=dforder,kind='line',ci=None)

# %%
sns.relplot('Year','Sales',data=dforder,kind='line',ci='sd')

# %%
sns.relplot('Year','Sales',data=dforder,kind='line',ci=None,estimator=None)

# %%
sns.relplot('Year','Sales',data=dforder,kind='line',ci=None,estimator=sum)

# %%
sns.relplot('Year','Sales',data=dforder,kind='line',ci=None,estimator=sum,hue='Ship Mode')
