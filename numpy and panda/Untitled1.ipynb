# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cf2 = df1.astype({"SibSp":float})
cf2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.Categorical(df1['Sex'])
# Out:
# [male, female, female, female, male, ..., male, female, female, male, male]
# Length: 891
# Categories (2, object): [female, male]

# %%
def GetGender(gen):
    if gen == 'male':
        return 1
    else:
        return 0

# %%
df1["Gender"]=df1['Sex'].apply(GetGender)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
pd.Categorical(df1['Embarked'])
# Out:
# [S, C, S, S, S, ..., S, S, S, C, Q]
# Length: 891
# Categories (3, object): [C, Q, S]

# %%
# create new column - EmbarkedNew --- C-1,Q-2,S-3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Gender       891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
def GetEmb(em):
    if em == 'C':
        return 1
    elif em == 'Q':
        return 2
    elif em == 'S':
        return 3
    else:
        return 0

# %%
df1["EmbarkedNew"]=df1['Embarked'].apply(GetEmb)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1[df1['EmbarkedNew']==0]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Gender  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN       0
# 829  female  62.0      0      0  113572  80.0   B28      NaN       0
#
#      EmbarkedNew
# 61             0
# 829            0

# %%
df1.drop([61,829],inplace=True)
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# <ipython-input-36-3d53e8e5f604> in <module>
# ----> 1 df1.drop([61,829],inplace=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df1.shape
# Out:
# (889, 14)

# %%
df1.drop('Sex',axis=1,inplace=True)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Gender  EmbarkedNew
# 0         A/5 21171   7.2500   NaN        S       1            3
# 1          PC 17599  71.2833   C85        C       0            1
# 2  STON/O2. 3101282   7.9250   NaN        S       0            3
# ...

# %%
df1['Cabin'].value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F2             3
# F33            3
#               ..
# E36            1
# A6             1
# F E69          1
# B71            1
# C118           1
# Name: Cabin, Length: 146, dtype: int64

# %%
js = pd.read_json(r'DataSet/example.json')

# %%
js
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
js = pd.read_html(r'DataSet/fdic_failed_bank_list.html')

# %%
js
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
len(js)
# Out:
# 1

# %%
df2=js[0]

# %%
df2
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
ls=["ad",'affa','adf']
df3=pd.DataFrame(ls)

# %%
df3
# Out:
#       0
# 0    ad
# 1  affa
# 2   adf

# %%
ls=["ad",'affa','adf']
ls2=["asd",'gd']

# %%
zip(ls,ls2)

# %%
list(zip(ls,ls2))
# Out:
# [('ad', 'asd'), ('affa', 'gd')]

# %%
df2=pd.DataFrame(list(zip(ls,ls2)),columns=["ento1",'ento2'])

# %%
df2.set_index('ento1')
# Out:
#       ento2
# ento1
# ad      asd
# affa     gd

# %%
df1.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name   Age  SibSp  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 6                              McCarthy, Mr. Timothy J  54.0      0      0
# 10                     Sandstrom, Miss. Marguerite Rut   4.0      1      1
# 11                            Bonnell, Miss. Elizabeth  58.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
df1.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                               Heikkinen, Miss. Laina      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                             Allen, Mr. William Henry      0      0
# ..                                                 ...    ...    ...
# ...

# %%
df2=df1[20:30]

# %%
df2.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked       False
# dtype: bool

# %%
df2[df2.isnull().any(1)]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
#
#     Parch  Ticket     Fare Cabin Embarked
# ...

# %%
#notnull

# %%
data = pd.notnull(df2['Age'])
data
# Out:
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26    False
# 27     True
# 28    False
# 29    False
# Name: Age, dtype: bool

# %%
df2.dropna(thresh=5)
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %%
df2.fillna("###")
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex  Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male   35      0
# 21                              Beesley, Mr. Lawrence    male   34      0
# 22                        McGowan, Miss. Anna "Annie"  female   15      0
# 23                       Sloper, Mr. William Thompson    male   28      0
# 24                      Palsson, Miss. Torborg Danira  female    8      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# ...

# %%
ageav=round(df1['Age'].mean(),1)

# %%
df1['Age']=df1['Age'].fillna(ageav)

# %%
df1[20:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %%
#replace

# %%
df4 = df1.replace(to_replace=np.nan,value="###")

# %%
df4[20:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
#
#                                                  Name     Sex  Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male   35      0
# 21                              Beesley, Mr. Lawrence    male   34      0
# 22                        McGowan, Miss. Anna "Annie"  female   15      0
# 23                       Sloper, Mr. William Thompson    male   28      0
# 24                      Palsson, Miss. Torborg Danira  female    8      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female   38      1
# ...

# %%
df4 = df1.replace(to_replace='female',value="F")

# %%
df4 = df4.replace(to_replace='male',value="M")

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   M  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1
# 2                               Heikkinen, Miss. Laina   F  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1
# 4                             Allen, Mr. William Henry   M  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
#miss values to NaN
missingval=['n/a','na','..']
df5 = pd.read_csv(r'https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv',na_values=missingval)
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dic1={'1':[1,1,4,5],'2':[2,2,3,4,]}

# %%
df5=pd.DataFrame(dic1)

# %%
df5
# Out:
#    1  2
# 0  1  2
# 1  1  2
# 2  4  3
# 3  5  4

# %%
df5.drop_duplicates()
# Out:
#    1  2
# 0  1  2
# 2  4  3
# 3  5  4

# %%
df6 = pd.read_csv('https://raw.githubusercontent.com/codebasics/py/master/pandas/7_group_by/weather_by_cities.csv')

# %%
df6
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
wrgb=df6.groupby(['city'])

# %%
for key,value in wrgb:
    print(key,value)
# Out:
# mumbai         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
wrgb.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
max(wrgb.get_group('new york')['temperature'])
# Out:
# 36

# %%
wrgb.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
#Q. dataframe concatination, merging,

# %%
#https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %%
#print first 5 and last 7 records 
# print total records and type of variables 
#Print the name of all the columns. 
#How is the dataset indexed? 
#Which was the most ordered item? and How many items were ordered? 
#What was the most ordered item in the choice_description column? 
#How much was the revenue for the period in the dataset?

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv ',sep='\t')

# %%
df1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df1.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df1.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
grname=df1.groupby('item_name')
m=grname.sum()
m.sort_values('quantity',ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
grname=df1.groupby('choice_description')
m=grname.sum()
m.sort_values('quantity',ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e9d7f65d9e16> in <module>
# ----> 1 df1['price']=int(df1['quantity'][1:])*int(df1['item_price'][1:])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in wrapper(self)
#     110         if len(self) == 1:
#     111             return converter(self.iloc[0])
# --> 112         raise TypeError(f"cannot convert the series to {converter}")
#     113
#     114     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#             price
# 0             NaN
# 1          $3.39
# 2          $3.39
# 3          $2.39
# 4  $16.98 $16.98

# %%
def getPrice(a):
    return float(a[1:])

# %%
df1["Tprice"]=df1['item_price'].apply(getPrice)


df1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#             price  Tprice  Totprice
# 0             NaN    2.39       NaN
# 1          $3.39     3.39       NaN
# 2          $3.39     3.39       NaN
# 3          $2.39     2.39       NaN
# ...

# %%
# def totalcost(q):
#     return q[0]*q[1]
# df1["Totprice"]=df1[['quantity','Tprice']].apply(totalcost)
# df1.head()
df1['TotPrice']=df1['quantity']*df1['Tprice']
df1['TotPrice'].sum()
# Out:
# 39237.02

# %%
df2=pd.DataFrame({'Name':['Babu','Suni','Suresh']})

# %%
df3=pd.DataFrame({'Age':[12,13,15]})

# %%
pd.concat([df2,df3],axis=0)
# Out:
#      Name   Age
# 0    Babu   NaN
# 1    Suni   NaN
# 2  Suresh   NaN
# 0     NaN  12.0
# 1     NaN  13.0
# 2     NaN  15.0

# %%
pd.concat([df2,df3],axis=1)
# Out:
#      Name  Age
# 0    Babu   12
# 1    Suni   13
# 2  Suresh   15

# %% [markdown]
# Numpy

# %% [markdown]
# #used for working with array and matrices
# #large collection of mathematical function for array and matrices
# #when ever you develop AI model you will be passing numerical data(images,audio,tabular,text) in numerical form
# #any kind of Al / ML you need to use numpy

# %%
df1=pd.read_csv('test.csv')

# %%
df1
# Out:
#     Name    Ph
# 0    Arj  99.0
# 1  Arjun   NaN

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#     Name  Ph
# 1  Arjun NaN
