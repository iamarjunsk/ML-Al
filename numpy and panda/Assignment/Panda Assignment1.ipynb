# %%
import pandas as pd

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv ',sep='\t')

# %%
#print first 5 and last 7 records

# %%
df1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df1.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
# print total records and type of variables
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#Print the name of all the columns.
df1.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#How is the dataset indexed?
df1.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Which was the most ordered item? and How many items were ordered?
df1.groupby('item_name').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
#What was the most ordered item in the choice_description column?
df1.groupby('choice_description').sum().sort_values('quantity',ascending=False).head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
#Turn the item price into a float
def getPrice(a):
    return float(a[1:])

df1["Tprice"]=df1['item_price'].apply(getPrice)
df1.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  Tprice
# 0                                                NaN     $2.39     2.39
# 1                                       [Clementine]     $3.39     3.39
# 2                                            [Apple]     $3.39     3.39
# 3                                                NaN     $2.39     2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98    16.98

# %%
#print a data frame with only two columns item_name and item_price
df1[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# delete the duplicates in item_name and quantity
df1[['item_name','quantity']].drop_duplicates()
# Out:
#                                   item_name  quantity
# 0              Chips and Fresh Tomato Salsa         1
# 1                                      Izze         1
# 2                          Nantucket Nectar         1
# 3     Chips and Tomatillo-Green Chili Salsa         1
# 4                              Chicken Bowl         2
# ...                                     ...       ...
# 3890                  Carnitas Crispy Tacos         2
# 3973                      Canned Soft Drink         4
# 4152                          Bottled Water        10
# 4354                       Steak Soft Tacos         2
# 4489                    Chips and Guacamole         4
#
# [103 rows x 2 columns]

# %%
# select only the products with quantity equals to 1
df1[df1['quantity']==1]['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 5                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4355, dtype: object

# %%
# select only the item_name and item_price columns
df1[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# sort item from the most to less expensive
df1.sort_values('item_price',ascending=False)
# Out:
#       order_id  quantity            item_name  \
# 2624      1042         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# ...        ...       ...                  ...
# 3145      1254         1          Canned Soda
# 414        180         1          Canned Soda
# 3162      1262         1          Canned Soda
# 821        338         1          Canned Soda
# 1457       591         1          Canned Soda
#
#                                      choice_description item_price  Tprice
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39     9.39
# 4419  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39     9.39
# 4036  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...     $9.39     9.39
# 1825  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39     9.39
# ...

# %%
#What was the quantity of the most expensive item ordered?
df1.sort_values('item_price',ascending=False).head(1)['quantity']
# Out:
# 2624    1
# Name: quantity, dtype: int64

# %%
#How many times were a Veggie Salad Bowl ordered?
df1[df1['item_name']=='Veggie Salad Bowl']['item_name'].count()
# Out:
# 18
